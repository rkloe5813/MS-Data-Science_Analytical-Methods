# %% [markdown]
# <a href="https://colab.research.google.com/github/rkloe5813/MS-Data-Science_Analytical-Methods/blob/main/Week1_doc1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io

# %%
# import csv from GitHub
url = 'https://raw.githubusercontent.com/rkloe5813/MS-Data-Science_Analytical-Methods/main/week1RandomData.csv'

# %%
# store imported csv as data frame
df1 = pd.read_csv(url, header=None)

# %%
df1
# Out:
#            0         1         2   ...        17        18        19
# 0    0.965407  0.325236  0.865122  ...  0.483025  0.388160  0.486676
# 1    0.301188  0.195493  0.299203  ...  0.883275  0.552690  0.647865
# 2    0.314684  0.075564  0.262861  ...  0.923513  0.262362  0.063139
# 3    0.912251  0.542659  0.280400  ...  0.094348  0.769356  0.737296
# 4    0.617178  0.315484  0.243953  ...  0.312019  0.185321  0.113801
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.765133  0.899000  0.280460  ...  0.152274  0.539564  0.778288
# 996  0.722835  0.592591  0.007103  ...  0.740086  0.665188  0.022152
# 997  0.742247  0.576259  0.053720  ...  0.316045  0.377090  0.649652
# 998  0.828206  0.082772  0.386395  ...  0.410950  0.841952  0.722636
# 999  0.572474  0.109395  0.795823  ...  0.210659  0.312958  0.886042
#
# [1000 rows x 20 columns]

# %%
print(df1)
# Out:
#            0         1         2   ...        17        18        19
# 0    0.965407  0.325236  0.865122  ...  0.483025  0.388160  0.486676
# 1    0.301188  0.195493  0.299203  ...  0.883275  0.552690  0.647865
# 2    0.314684  0.075564  0.262861  ...  0.923513  0.262362  0.063139
# 3    0.912251  0.542659  0.280400  ...  0.094348  0.769356  0.737296
# 4    0.617178  0.315484  0.243953  ...  0.312019  0.185321  0.113801
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.765133  0.899000  0.280460  ...  0.152274  0.539564  0.778288
# 996  0.722835  0.592591  0.007103  ...  0.740086  0.665188  0.022152
# 997  0.742247  0.576259  0.053720  ...  0.316045  0.377090  0.649652
# 998  0.828206  0.082772  0.386395  ...  0.410950  0.841952  0.722636
# 999  0.572474  0.109395  0.795823  ...  0.210659  0.312958  0.886042
#
# [1000 rows x 20 columns]

# %%
print(df1.corr())
# Out:
#           0         1         2   ...        17        18        19
# 0   1.000000 -0.076352 -0.017477  ... -0.063927  0.009770 -0.054276
# 1  -0.076352  1.000000  0.028620  ... -0.001437 -0.064650  0.049632
# 2  -0.017477  0.028620  1.000000  ... -0.046702 -0.034526  0.004737
# 3   0.027813 -0.036457 -0.008738  ...  0.001523 -0.010131  0.036041
# 4   0.054841 -0.016201 -0.034204  ... -0.057095  0.032845 -0.015249
# 5  -0.057968  0.033099 -0.012613  ...  0.033065  0.024439 -0.028006
# 6   0.038822 -0.001405  0.007072  ... -0.020442  0.005558  0.048566
# 7  -0.002075 -0.030454 -0.004356  ... -0.019937 -0.007429  0.021733
# 8   0.009208  0.055364  0.031888  ... -0.049003 -0.029078  0.038008
# 9   0.000975 -0.015559  0.021687  ... -0.009557 -0.038986 -0.028766
# 10  0.040011 -0.019788 -0.023350  ... -0.008713 -0.043591  0.021649
# 11 -0.010583 -0.051842  0.078042  ...  0.008201 -0.032452 -0.060198
# 12  0.029566 -0.015830  0.040275  ... -0.003423 -0.021364  0.010179
# ...

# %%
testwrite = df1.corr()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
testwrite.to_csv("/content/drive/My Drive/Colab Notebooks/testwrite.csv")

# %%
plt.figure()
sns.heatmap(df1.corr(),
            vmin=-1,
            cmap='coolwarm');

# %%
df1
# Out:
#            0         1         2   ...        17        18        19
# 0    0.965407  0.325236  0.865122  ...  0.483025  0.388160  0.486676
# 1    0.301188  0.195493  0.299203  ...  0.883275  0.552690  0.647865
# 2    0.314684  0.075564  0.262861  ...  0.923513  0.262362  0.063139
# 3    0.912251  0.542659  0.280400  ...  0.094348  0.769356  0.737296
# 4    0.617178  0.315484  0.243953  ...  0.312019  0.185321  0.113801
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.765133  0.899000  0.280460  ...  0.152274  0.539564  0.778288
# 996  0.722835  0.592591  0.007103  ...  0.740086  0.665188  0.022152
# 997  0.742247  0.576259  0.053720  ...  0.316045  0.377090  0.649652
# 998  0.828206  0.082772  0.386395  ...  0.410950  0.841952  0.722636
# 999  0.572474  0.109395  0.795823  ...  0.210659  0.312958  0.886042
#
# [1000 rows x 20 columns]

# %%
# show histogram of the correlated data
plt.hist(df1.corr())
# Out:
# (array([[12.,  7.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [15.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [15.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [12.,  7.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [14.,  5.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [11.,  8.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [12.,  7.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [15.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [13.,  6.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [16.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [11.,  8.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [15.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [14.,  5.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [14.,  5.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [14.,  5.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [14.,  5.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
# ...

# %%
# check datatype
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# transpose the dataframe to flip rows and columns
df2 = pd.DataFrame.transpose(df1)

# %%
df2.head()
# Out:
#         0         1         2    ...       997       998       999
# 0  0.965407  0.301188  0.314684  ...  0.742247  0.828206  0.572474
# 1  0.325236  0.195493  0.075564  ...  0.576259  0.082772  0.109395
# 2  0.865122  0.299203  0.262861  ...  0.053720  0.386395  0.795823
# 3  0.614286  0.032313  0.198651  ...  0.561018  0.190909  0.379951
# 4  0.222255  0.788408  0.398343  ...  0.806069  0.554432  0.693887
#
# [5 rows x 1000 columns]

# %%
# write the transposed data to a csv
# path = '/content/drive/MyDrive/Colab Notebooks/RandDataTrsp.csv'
df2.to_csv("/content/drive/My Drive/Colab Notebooks/RandDataTrsp.csv")

# %%
# show correlation matrix
print(df2.corr())
# Out:
#           0         1         2    ...       997       998       999
# 0    1.000000 -0.336618  0.287422  ...  0.306464 -0.087250  0.316350
# 1   -0.336618  1.000000  0.340119  ...  0.040834  0.027526  0.137951
# 2    0.287422  0.340119  1.000000  ...  0.058201  0.057838 -0.122038
# 3   -0.066108  0.030187 -0.190830  ...  0.308816 -0.018652  0.209162
# 4    0.199528 -0.268115  0.198525  ...  0.349120 -0.170420 -0.190220
# ..        ...       ...       ...  ...       ...       ...       ...
# 995 -0.246832  0.051786 -0.414016  ...  0.147524  0.107993 -0.071138
# 996 -0.384056  0.240364  0.129336  ... -0.082442  0.226797 -0.277569
# 997  0.306464  0.040834  0.058201  ...  1.000000 -0.437737  0.194979
# 998 -0.087250  0.027526  0.057838  ... -0.437737  1.000000 -0.026636
# 999  0.316350  0.137951 -0.122038  ...  0.194979 -0.026636  1.000000
#
# [1000 rows x 1000 columns]

# %%
# show heatmap of the transposed correlation
plt.figure()
sns.heatmap(df2.corr(),
            vmin=-1,
            cmap='coolwarm');

# %%
# show a histogram of the transposed correlation data
plt.hist(df2.corr())
# Out:
# (array([[  1.,   9.,  90., ...,  25.,   1.,   1.],
#         [  0.,  14.,  77., ...,  26.,   2.,   1.],
#         [  1.,  19., 107., ...,  28.,   3.,   1.],
#         ...,
#         [  1.,  18.,  89., ...,  21.,   4.,   1.],
#         [  1.,  17.,  94., ...,  14.,   3.,   1.],
#         [  1.,  13.,  84., ...,  29.,   2.,   1.]]),
#  array([-0.85094479, -0.66585031, -0.48075583, -0.29566135, -0.11056687,
#          0.07452761,  0.25962209,  0.44471656,  0.62981104,  0.81490552,
#          1.        ]),
#  <a list of 1000 Lists of Patches objects>)
